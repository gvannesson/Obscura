# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')       # downloads the nano-model weights if needed
results = model('zidane.jpg')
# Since you only passed one image, grab results[0]:
res = results[0]

res.plot()
res.show()
# Out:
# image 1/1 /home/s-thorez/Documents/Obscura/src/zidane.jpg: 384x640 2 persons, 1 tie, 160.8ms
# Speed: 2.6ms preprocess, 160.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Ouverture dans une session de navigateur existante.
